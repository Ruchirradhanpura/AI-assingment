# %% [markdown]
# <a href="https://colab.research.google.com/github/Ruchirradhanpura/AI-assingment/blob/main/Ruchir.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
x_cgpa =[2,3,4,5]
Y_salary=[100,200,300,400]
plt.bar(x_cgpa,Y_salary)
plt.title("salary and cgpa graph")
plt.xlabel("cgpa")
plt.ylabel("salary")
plt.show()
